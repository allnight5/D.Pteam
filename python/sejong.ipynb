# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

plt.rcParams['axes.unicode_minus'] = False 

poplu2=pd.read_csv('../data/2016se.csv', thousands=',', encoding='euc-kr')
poplu3=pd.read_csv('../data/2017se.csv', thousands=',', encoding='euc-kr')
poplu2.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  발생건수(건)  \
# 0  세종  2016-01-01      -5.7      -7.3      -3.6        36.0       60
# 1  세종  2016-01-02      -5.0      -9.9      -0.7        34.0      172
# 2  세종  2016-01-03      -3.7     -11.2       2.5        51.0      130
# 3  세종  2016-01-04       1.9      -2.3       9.8        51.0       47
# 4  세종  2016-01-05       3.6      -3.4       8.5        50.0      192
#
#    최저기온위험지수  일교차위험지수  습도위험지수
# 0       NaN      NaN     NaN
# 1       NaN      NaN     NaN
# 2       NaN      NaN     NaN
# 3       NaN      NaN     NaN
# 4       NaN      NaN     NaN

# %%
#습도는 절대값으로 한다.
for i in poplu2.index:
    if poplu2.values[i,2] < 17 :
        if poplu2.values[i,5] >70:
            poplu2['습도위험지수'].values[i] = '1'
        elif 59< poplu2.values[i,5] <70:
            poplu2['습도위험지수'].values[i] = '2'
        elif 49< poplu2.values[i,5] <60:
            poplu2['습도위험지수'].values[i] = '3'
        else:
            poplu2['습도위험지수'].values[i] = '4'
    elif 17<poplu2.values[i,2] < 21:
        if poplu2.values[i,5] >60:
            poplu2['습도위험지수'].values[i] = '1'
        elif 49< poplu2.values[i,5] <60:
            poplu2['습도위험지수'].values[i] = '2'
        elif 39< poplu2.values[i,5] <50:
            poplu2['습도위험지수'].values[i] = '3'
        else:
            poplu2['습도위험지수'].values[i] = '4'
            
    elif 20<poplu2.values[i,2] < 24:
        if poplu2.values[i,5] >50:
            poplu2['습도위험지수'].values[i] = '1'
        elif 39< poplu2.values[i,5] <50:
            poplu2['습도위험지수'].values[i] = '2'
        elif 29< poplu2.values[i,5] <40:
            poplu2['습도위험지수'].values[i] = '3'
        else:
            poplu2['습도위험지수'].values[i] = '4'
    elif poplu2.values[i,2] > 23:
        if poplu2.values[i,5] >40:
            poplu2['습도위험지수'].values[i] = '1'
        elif 29< poplu2.values[i,5] <40:
            poplu2['습도위험지수'].values[i] = '2'
        elif 19< poplu2.values[i,5] <30:
            poplu2['습도위험지수'].values[i] = '3'
        else:
            poplu2['습도위험지수'].values[i] = '4'
poplu2.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  발생건수(건)  \
# 0  세종  2016-01-01      -5.7      -7.3      -3.6        36.0       60
# 1  세종  2016-01-02      -5.0      -9.9      -0.7        34.0      172
# 2  세종  2016-01-03      -3.7     -11.2       2.5        51.0      130
# 3  세종  2016-01-04       1.9      -2.3       9.8        51.0       47
# 4  세종  2016-01-05       3.6      -3.4       8.5        50.0      192
#
#    최저기온위험지수  일교차위험지수  습도위험지수
# 0       NaN      NaN     4.0
# 1       NaN      NaN     4.0
# 2       NaN      NaN     3.0
# 3       NaN      NaN     3.0
# 4       NaN      NaN     3.0

# %%
#습도는 절대값으로 한다.
for i in poplu3.index:
    if poplu3.values[i,2] < 17 :
        if poplu3.values[i,5] >70:
            poplu3['습도위험지수'].values[i] = '1'
        elif 59< poplu3.values[i,5] <70:
            poplu3['습도위험지수'].values[i] = '2'
        elif 49< poplu3.values[i,5] <60:
            poplu3['습도위험지수'].values[i] = '3'
        else:
            poplu3['습도위험지수'].values[i] = '4'
    elif 17<poplu3.values[i,2] < 21:
        if poplu3.values[i,5] >60:
            poplu3['습도위험지수'].values[i] = '1'
        elif 49< poplu3.values[i,5] <60:
            poplu3['습도위험지수'].values[i] = '2'
        elif 39< poplu3.values[i,5] <50:
            poplu3['습도위험지수'].values[i] = '3'
        else:
            poplu3['습도위험지수'].values[i] = '4'
            
    elif 20<poplu3.values[i,2] < 24:
        if poplu3.values[i,5] >50:
            poplu3['습도위험지수'].values[i] = '1'
        elif 39< poplu3.values[i,5] <50:
            poplu3['습도위험지수'].values[i] = '2'
        elif 29< poplu3.values[i,5] <40:
            poplu3['습도위험지수'].values[i] = '3'
        else:
            poplu3['습도위험지수'].values[i] = '4'
    elif poplu3.values[i,2] > 23:
        if poplu3.values[i,5] >40:
            poplu3['습도위험지수'].values[i] = '1'
        elif 29< poplu3.values[i,5] <40:
            poplu3['습도위험지수'].values[i] = '2'
        elif 19< poplu3.values[i,5] <30:
            poplu3['습도위험지수'].values[i] = '3'
        else:
            poplu3['습도위험지수'].values[i] = '4'

poplu3.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  최저기온위험지수  \
# 0  세종  2017-01-01       1.8      -4.6       6.8        57.0       NaN
# 1  세종  2017-01-02       6.1       1.9      12.9        53.0       NaN
# 2  세종  2017-01-03       5.6       0.7      12.1        63.0       NaN
# 3  세종  2017-01-04       3.9      -1.8       7.3        33.0       NaN
# 4  세종  2017-01-05      -0.9      -4.5       2.5        29.0       NaN
#
#    일교차위험지수  습도위험지수
# 0      NaN     3.0
# 1      NaN     3.0
# 2      NaN     2.0
# 3      NaN     4.0
# 4      NaN     4.0

# %%
#일교차를 구한다.
poplu2['일교차'] = poplu2['최고기온(°C)'] -  poplu2['최저기온(°C)']
poplu3['일교차'] = poplu3['최고기온(°C)'] -  poplu3['최저기온(°C)']
poplu2.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  발생건수(건)  \
# 0  세종  2016-01-01      -5.7      -7.3      -3.6        36.0       60
# 1  세종  2016-01-02      -5.0      -9.9      -0.7        34.0      172
# 2  세종  2016-01-03      -3.7     -11.2       2.5        51.0      130
# 3  세종  2016-01-04       1.9      -2.3       9.8        51.0       47
# 4  세종  2016-01-05       3.6      -3.4       8.5        50.0      192
#
#    최저기온위험지수  일교차위험지수  습도위험지수   일교차
# 0       NaN      NaN     4.0   3.7
# 1       NaN      NaN     4.0   9.2
# 2       NaN      NaN     3.0  13.7
# 3       NaN      NaN     3.0  12.1
# 4       NaN      NaN     3.0  11.9

# %%
#각 지역별로 이루어져있는 값을 가지고 지역마다 다르게 분석한다.
for i in poplu2.index: 
    if poplu2.values[i,3] <-7.7 or 30=<poplu2.values[1,2]: 
        poplu2['최저기온위험지수'].values[i] = '4' 
    elif -7.7<=poplu2.values[i,3] <-0.5:
        poplu2['최저기온위험지수'].values[i] = '3' 
    elif -0.5<=poplu2.values[i,3] < 12.6:
        poplu2['최저기온위험지수'].values[i] = '2'  
    elif 12.6<=poplu2.values[i,3] <30:
        poplu2['최저기온위험지수'].values[i] = '1'  
        
    if poplu2.values[i,9] < 8.6 : 
        poplu2['일교차위험지수'].values[i] = '1' 
    elif 8.6<= poplu2.values[i,9] < 12.3: 
        poplu2['일교차위험지수'].values[i] = '2'  
    elif 12.3<=poplu2.values[i,9] < 15.8:  
        poplu2['일교차위험지수'].values[i] = '3'  
    elif 15.8<= poplu2.values[i,9] : 
        poplu2['일교차위험지수'].values[i] = '4' 

poplu2.head(10)
# Out:
#   File "<ipython-input-32-4e261c295517>", line 2
#     if poplu2.values[i,3] <-7.7 or 30=<poplu2.values[1,2]:
#                                      ^
# SyntaxError: invalid syntax

# %%
for i in poplu3.index:    
    if poplu3.values[i,3] <6 or 29<poplu3.values[1,2]:
        poplu3['최저기온위험지수'].values[i] = '4' 
    elif 5<poplu3.values[i,3] <15:
        poplu3['최저기온위험지수'].values[i] = '3' 
    elif 14<poplu3.values[i,3] <25:
        poplu3['최저기온위험지수'].values[i] = '2'  
    elif 24< poplu3.values[i,3] <30:
        poplu3['최저기온위험지수'].values[i] = '1'  
        
    if poplu3.values[i,9] < 10.1 : 
        poplu3['일교차위험지수'].values[i] = '1' 
    elif 10.1<= poplu3.values[i,9] < 14: 
        poplu3['일교차위험지수'].values[i] = '2'  
    elif 14<=poplu3.values[i,9] < 17.8:  
        poplu3['일교차위험지수'].values[i] = '3'  
    elif 17.8<= poplu3.values[i,9] : 
        poplu3['일교차위험지수'].values[i] = '4' 

poplu3.head(10)
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  최저기온위험지수  \
# 0  세종  2017-01-01       1.8      -4.6       6.8        57.0       4.0
# 1  세종  2017-01-02       6.1       1.9      12.9        53.0       4.0
# 2  세종  2017-01-03       5.6       0.7      12.1        63.0       4.0
# 3  세종  2017-01-04       3.9      -1.8       7.3        33.0       4.0
# 4  세종  2017-01-05      -0.9      -4.5       2.5        29.0       4.0
# 5  세종  2017-01-06      -0.1      -5.9       3.9        47.0       4.0
# 6  세종  2017-01-07      -0.5      -2.4       2.9        43.0       4.0
# 7  세종  2017-01-08      -1.3      -5.6       2.8        34.0       4.0
# 8  세종  2017-01-09       0.2      -2.1       4.8        50.0       4.0
# 9  세종  2017-01-10       0.3      -3.4       5.7        32.0       4.0
#
#    일교차위험지수  습도위험지수   일교차
# 0      2.0     3.0  11.4
# 1      2.0     3.0  11.0
# 2      2.0     2.0  11.4
# 3      1.0     4.0   9.1
# 4      1.0     4.0   7.0
# 5      1.0     4.0   9.8
# 6      1.0     4.0   5.3
# 7      1.0     4.0   8.4
# 8      1.0     3.0   6.9
# 9      1.0     4.0   9.1

# %%
poplu2['일교차비율'] = poplu2['일교차'].sum()
poplu2.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  발생건수(건)  \
# 0  세종  2016-01-01      -5.7      -7.3      -3.6        36.0       60
# 1  세종  2016-01-02      -5.0      -9.9      -0.7        34.0      172
# 2  세종  2016-01-03      -3.7     -11.2       2.5        51.0      130
# 3  세종  2016-01-04       1.9      -2.3       9.8        51.0       47
# 4  세종  2016-01-05       3.6      -3.4       8.5        50.0      192
#
#    최저기온위험지수  일교차위험지수  습도위험지수   일교차   일교차비율
# 0       4.0      1.0     4.0   3.7  3963.0
# 1       4.0      1.0     4.0   9.2  3963.0
# 2       4.0      1.0     3.0  13.7  3963.0
# 3       4.0      1.0     3.0  12.1  3963.0
# 4       4.0      1.0     3.0  11.9  3963.0

# %%
poplu2['2016비율'] = (poplu2['일교차']/poplu2['일교차비율'])*100

# %%
poplu2.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  발생건수(건)  \
# 0  세종  2016-01-01      -5.7      -7.3      -3.6        36.0       60
# 1  세종  2016-01-02      -5.0      -9.9      -0.7        34.0      172
# 2  세종  2016-01-03      -3.7     -11.2       2.5        51.0      130
# 3  세종  2016-01-04       1.9      -2.3       9.8        51.0       47
# 4  세종  2016-01-05       3.6      -3.4       8.5        50.0      192
#
#    최저기온위험지수  일교차위험지수  습도위험지수   일교차   일교차비율    2016비율
# 0       4.0      1.0     4.0   3.7  3963.0  0.093364
# 1       4.0      1.0     4.0   9.2  3963.0  0.232147
# 2       4.0      1.0     3.0  13.7  3963.0  0.345698
# 3       4.0      1.0     3.0  12.1  3963.0  0.305324
# 4       4.0      1.0     3.0  11.9  3963.0  0.300278

# %%
poplu2['일교차평균']=poplu2['일교차'].mean()

# %%
plt.figure(figsize=(30,10))
plt.scatter(poplu2.index,poplu2['2016비율'],s=100)
plt.xlabel('날짜')
plt.ylabel('발생건수(건)')
plt.grid()
plt.show()

# %%
poplu2['플마'] = poplu2['일교차']-poplu2['일교차평균']
poplu2.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  발생건수(건)  \
# 0  세종  2016-01-01      -5.7      -7.3      -3.6        36.0       60
# 1  세종  2016-01-02      -5.0      -9.9      -0.7        34.0      172
# 2  세종  2016-01-03      -3.7     -11.2       2.5        51.0      130
# 3  세종  2016-01-04       1.9      -2.3       9.8        51.0       47
# 4  세종  2016-01-05       3.6      -3.4       8.5        50.0      192
#
#    최저기온위험지수  일교차위험지수  습도위험지수   일교차   일교차비율    2016비율      일교차평균        플마
# 0       4.0      1.0     4.0   3.7  3963.0  0.093364  10.857534 -7.157534
# 1       4.0      1.0     4.0   9.2  3963.0  0.232147  10.857534 -1.657534
# 2       4.0      1.0     3.0  13.7  3963.0  0.345698  10.857534  2.842466
# 3       4.0      1.0     3.0  12.1  3963.0  0.305324  10.857534  1.242466
# 4       4.0      1.0     3.0  11.9  3963.0  0.300278  10.857534  1.042466

# %%
colormap=poplu2['플마']
plt.figure(figsize=(30,10))
plt.scatter(poplu2.index,poplu2['플마'],s=100,c=colormap,marker='^')
plt.colorbar()
plt.xlabel('날짜')
plt.ylabel('플러스마이너스')
plt.grid()
plt.show()

# %%
for i in poplu3.index:    
    if poplu3.values[i,3] <-7.7 or 29<poplu3.values[1,2]:
        poplu3['최저기온위험지수'].values[i] = '4' 
    elif -7.7<=poplu3.values[i,3] <-0.5:
        poplu3['최저기온위험지수'].values[i] = '3' 
    elif -0.5<=poplu3.values[i,3] < 12.6:
        poplu3['최저기온위험지수'].values[i] = '2'  
    elif 12.6<=poplu3.values[i,3] <30:
        poplu3['최저기온위험지수'].values[i] = '1'  
        
    if poplu3.values[i,9] < 8.6 : 
        poplu3['일교차위험지수'].values[i] = '1' 
    elif 8.6<= poplu3.values[i,9] < 12.3: 
        poplu3['일교차위험지수'].values[i] = '2'  
    elif 12.3<=poplu3.values[i,9] < 15.8:  
        poplu3['일교차위험지수'].values[i] = '3'  
    elif 15.8<= poplu3.values[i,9] : 
        poplu3['일교차위험지수'].values[i] = '4' 

poplu3
# Out:
#      지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  최저기온위험지수  \
# 0    세종  2017-01-01       1.8      -4.6       6.8        57.0       3.0
# 1    세종  2017-01-02       6.1       1.9      12.9        53.0       2.0
# 2    세종  2017-01-03       5.6       0.7      12.1        63.0       2.0
# 3    세종  2017-01-04       3.9      -1.8       7.3        33.0       3.0
# 4    세종  2017-01-05      -0.9      -4.5       2.5        29.0       3.0
# 5    세종  2017-01-06      -0.1      -5.9       3.9        47.0       3.0
# 6    세종  2017-01-07      -0.5      -2.4       2.9        43.0       3.0
# 7    세종  2017-01-08      -1.3      -5.6       2.8        34.0       3.0
# 8    세종  2017-01-09       0.2      -2.1       4.8        50.0       3.0
# 9    세종  2017-01-10       0.3      -3.4       5.7        32.0       3.0
# 10   세종  2017-01-11      -2.5      -5.7       2.1        38.0       3.0
# 11   세종  2017-01-12      -3.7      -9.9       1.9        41.0       4.0
# 12   세종  2017-01-13      -2.1      -4.7       1.9        55.4       3.0
# 13   세종  2017-01-14      -2.6      -8.9       2.3        32.0       4.0
# 14   세종  2017-01-15      -0.1      -4.4       5.4        44.0       3.0
# 15   세종  2017-01-16       0.6      -3.8       6.2        52.0       3.0
# 16   세종  2017-01-17       2.8      -1.2       7.4        50.0       3.0
# 17   세종  2017-01-18      -4.2      -8.9       1.1        54.0       4.0
# 18   세종  2017-01-19      -9.1     -11.4      -5.8        53.0       4.0
# 19   세종  2017-01-20     -10.9     -16.8      -5.7        53.0       4.0
# 20   세종  2017-01-21      -7.5     -13.3      -1.8        43.0       4.0
# 21   세종  2017-01-22      -7.5     -14.9      -1.9        37.0       4.0
# 22   세종  2017-01-23      -8.9     -12.4      -4.8        36.0       4.0
# 23   세종  2017-01-24     -12.7     -15.4      -9.9        56.0       4.0
# 24   세종  2017-01-25     -10.9     -18.6      -4.0        55.0       4.0
# 25   세종  2017-01-26      -3.5      -8.4       3.0        50.0       4.0
# 26   세종  2017-01-27      -3.3      -9.6       4.3        51.0       4.0
# 27   세종  2017-01-28      -1.0      -8.8       3.1        54.0       4.0
# 28   세종  2017-01-29       2.0      -0.6       5.8        45.0       3.0
# 29   세종  2017-01-30      -0.3      -5.6       5.5        60.0       3.0
# ..   ..         ...       ...       ...       ...         ...       ...
# 335  세종  2017-12-02      -0.3      -6.7       7.1        31.0       3.0
# 336  세종  2017-12-03       1.4      -5.7      10.0        40.0       3.0
# 337  세종  2017-12-04       3.0      -2.1       8.2        49.2       3.0
# 338  세종  2017-12-05       6.6       1.6      13.2        48.0       2.0
# 339  세종  2017-12-06      -0.5      -6.3       4.8        16.0       3.0
# 340  세종  2017-12-07       0.6      -7.4       7.7        50.0       3.0
# 341  세종  2017-12-08       2.1      -4.5       7.5        59.5       3.0
# 342  세종  2017-12-09       3.4      -1.0       6.7        43.0       3.0
# 343  세종  2017-12-10      -1.7      -7.3       5.0        21.0       3.0
# 344  세종  2017-12-11      -3.1      -9.3       5.8        21.0       4.0
# 345  세종  2017-12-12       2.5      -6.3      11.1        29.0       3.0
# 346  세종  2017-12-13       2.5      -2.1       8.4        53.0       3.0
# 347  세종  2017-12-14       0.2      -2.8       2.6        59.0       3.0
# 348  세종  2017-12-15      -2.2      -5.1       1.1        31.2       3.0
# 349  세종  2017-12-16      -4.4     -12.0       1.4        29.1       4.0
# 350  세종  2017-12-17       2.6      -2.7      10.3        48.0       3.0
# 351  세종  2017-12-18       2.0      -3.5       8.9        56.0       3.0
# 352  세종  2017-12-19       6.4       2.0      10.8        70.0       2.0
# 353  세종  2017-12-20       5.4       1.2      12.5        50.0       2.0
# 354  세종  2017-12-21       7.5      -1.1      13.7        55.2       3.0
# 355  세종  2017-12-22       7.5       3.1      14.0        71.7       2.0
# 356  세종  2017-12-23      -0.3      -1.9       3.2        68.3       3.0
# 357  세종  2017-12-24      -2.1      -4.3       0.5        59.0       3.0
# 358  세종  2017-12-25      -0.4      -7.1       6.4        61.0       3.0
# 359  세종  2017-12-26       2.4       0.7       4.2        77.0       2.0
# 360  세종  2017-12-27      -0.2      -5.6       2.4        35.0       3.0
# 361  세종  2017-12-28      -3.6     -10.3       2.9        28.0       4.0
# 362  세종  2017-12-29      -3.7      -6.8      -0.4        27.2       3.0
# 363  세종  2017-12-30      -3.8     -11.1       3.5        41.0       4.0
# 364  세종  2017-12-31       0.4      -4.4       4.6        66.0       3.0
#
#      일교차위험지수  습도위험지수   일교차
# 0        2.0     3.0  11.4
# 1        2.0     3.0  11.0
# 2        2.0     2.0  11.4
# 3        2.0     4.0   9.1
# 4        1.0     4.0   7.0
# 5        2.0     4.0   9.8
# 6        1.0     4.0   5.3
# 7        1.0     4.0   8.4
# 8        1.0     3.0   6.9
# 9        2.0     4.0   9.1
# 10       1.0     4.0   7.8
# 11       2.0     4.0  11.8
# 12       1.0     3.0   6.6
# 13       2.0     4.0  11.2
# 14       2.0     4.0   9.8
# 15       2.0     3.0  10.0
# 16       2.0     3.0   8.6
# 17       2.0     3.0  10.0
# 18       1.0     3.0   5.6
# 19       2.0     3.0  11.1
# 20       2.0     4.0  11.5
# 21       3.0     4.0  13.0
# 22       1.0     4.0   7.6
# 23       1.0     3.0   5.5
# 24       3.0     3.0  14.6
# 25       2.0     3.0  11.4
# 26       3.0     3.0  13.9
# 27       2.0     3.0  11.9
# 28       1.0     4.0   6.4
# 29       2.0     2.0  11.1
# ..       ...     ...   ...
# 335      3.0     4.0  13.8
# 336      3.0     4.0  15.7
# 337      2.0     3.0  10.3
# 338      2.0     4.0  11.6
# 339      2.0     4.0  11.1
# 340      3.0     3.0  15.1
# 341      2.0     2.0  12.0
# 342      1.0     4.0   7.7
# 343      3.0     4.0  12.3
# 344      3.0     4.0  15.1
# 345      4.0     4.0  17.4
# 346      2.0     3.0  10.5
# 347      1.0     3.0   5.4
# 348      1.0     4.0   6.2
# 349      3.0     4.0  13.4
# 350      3.0     4.0  13.0
# 351      3.0     3.0  12.4
# 352      2.0     4.0   8.8
# 353      2.0     3.0  11.3
# 354      3.0     3.0  14.8
# 355      2.0     1.0  10.9
# 356      1.0     2.0   5.1
# 357      1.0     3.0   4.8
# 358      3.0     2.0  13.5
# 359      1.0     1.0   3.5
# 360      1.0     4.0   8.0
# 361      3.0     4.0  13.2
# 362      1.0     4.0   6.4
# 363      3.0     4.0  14.6
# 364      2.0     2.0   9.0
#
# [365 rows x 10 columns]

# %%
plt.figure(figsize=(10,6))
plt.plot(poplu3.index,poplu3['일교차위험지수'], color = 'green')
plt.xlabel('날짜')
plt.ylabel('일교차위험지수')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(poplu3.index,poplu3['습도위험지수'], color = 'green')
plt.xlabel('날짜')
plt.ylabel('습도위험지수')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(poplu3.index,poplu3['최저기온위험지수'], color = 'green')
plt.xlabel('날짜')
plt.ylabel('최저기온위험지수')
plt.grid()
plt.show()

# %%
poplu4=pd.read_csv('../data/2016ojeon.csv', thousands=',', encoding='euc-kr')
poplu5=pd.read_csv('../data/2017ojeon.csv', thousands=',', encoding='euc-kr')
poplu4.head()
# Out:
#            일시  평균 오존전량(DU)  오존위험지수
# 0  2016-01-01        354.9     NaN
# 1  2016-01-02        365.5     NaN
# 2  2016-01-03        373.2     NaN
# 3  2016-01-04        339.8     NaN
# 4  2016-01-05        269.9     NaN

# %%
for i in poplu4.index:    
    if poplu4.values[i,1] < 300:
        poplu4['오존위험지수'].values[i] = '1'
    elif 300<=poplu4.values[i,1] <348.7:
        poplu4['오존위험지수'].values[i] = '2'
    elif 348.7<=poplu4.values[i,1] <386.4:
        poplu4['오존위험지수'].values[i] = '3'
    elif 386.4<= poplu4.values[i,1]:
        poplu4['오존위험지수'].values[i] = '4'
        
    if poplu5.values[i,1] < 300:
        poplu5['오존위험지수'].values[i] = '1'
    elif 300<=poplu5.values[i,1] <348.7:
        poplu5['오존위험지수'].values[i] = '2'
    elif 348.7<=poplu5.values[i,1] <386.4:
        poplu5['오존위험지수'].values[i] = '3'
    elif 386.4<= poplu5.values[i,1]:
        poplu5['오존위험지수'].values[i] = '4'
        
poplu4.head()
# Out:
#            일시  평균 오존전량(DU)  오존위험지수
# 0  2016-01-01        354.9     3.0
# 1  2016-01-02        365.5     3.0
# 2  2016-01-03        373.2     3.0
# 3  2016-01-04        339.8     2.0
# 4  2016-01-05        269.9     1.0

# %%
plt.figure(figsize=(10,6))
plt.plot(poplu4.index,poplu4['오존위험지수'], color = 'green')
plt.xlabel('날짜')
plt.ylabel('오존위험지수')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(poplu5.index,poplu5['오존위험지수'], color = 'green')
plt.xlabel('날짜')
plt.ylabel('오존위험지수')
plt.grid()
plt.show()

# %%
poplus16=pd.read_csv('../data/2016seseek.csv', thousands=',', encoding='euc-kr')
poplus17=pd.read_csv('../data/2017seseek.csv', thousands=',', encoding='euc-kr')
poplus16.head()
# Out:
#          날짜  시군구지역코드  발생건수(건)
# 0  20160101    36110       60
# 1  20160102    36110      172
# 2  20160103    36110      130
# 3  20160104    36110       47
# 4  20160105    36110      192

# %%
poplus16['환자평균'] = poplus16['발생건수(건)'].mean()
poplus17['환자평균'] = poplus17['발생건수(건)'].mean()
poplus16.head()
# Out:
#          날짜  시군구지역코드  발생건수(건)        환자평균
# 0  20160101    36110       60  177.961644
# 1  20160102    36110      172  177.961644
# 2  20160103    36110      130  177.961644
# 3  20160104    36110       47  177.961644
# 4  20160105    36110      192  177.961644

# %%
plt.figure(figsize=(10,6)) 
plt.scatter(poplus16.index,poplus16['발생건수(건)'],s=20,c=colormap,marker='^') 
plt.xlabel('날짜')
plt.ylabel('오존위험지수')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6)) 
plt.scatter(poplus17.index,poplus17['발생건수(건)'],s=20,c=colormap,marker='^') 
plt.xlabel('날짜')
plt.ylabel('오존위험지수')
plt.grid()
plt.show()

# %%
mintem1 = 0
diftem1 = 0
humi1 = 0
ojeon1 = 0
for i in poplus16.index:
    if poplus16.values[i,2] > poplus16.values[i,3]:
        if poplu2.values[i,7] >2 : mintem1 = mintem1 +1
        else : mintem1 = mintem1 -1

        if poplu2.values[i,8] >2 : diftem1 = diftem1 +1
        else : diftem1 = diftem1 -1
            
        if poplu2.values[i,9] >2 : humi1 = humi1 +1
        else : humi1 = humi1 -1 
        
        if poplu4.values[i,2] >2 : ojeon1 = ojeon1 +1
        else : ojeon1= ojeon1 -1

    else :
        if poplu2.values[i,7] <2 : mintem1 = mintem1 +1
        else : mintem1 = mintem1 -1

        if poplu2.values[i,8] <2 : diftem1 = diftem1 +1
        else : diftem1 = diftem1 -1
            
        if poplu2.values[i,9] <2 : humi1 = humi1 +1
        else : humi1 = humi1 -1 
        
        if poplu4.values[i,2] <2 : ojeon1 = ojeon1 +1
        else : ojeon1= ojeon1 -1

# %%
mintem1, diftem1, humi1, ojeon1
# Out:
# (-47, 5, 13, -215)

# %%
mintem2 = 0
diftem2 = 0
humi2 = 0
ojeon2 = 0
for i in poplus17.index:
    if poplus17.values[i,2] > poplus17.values[i,3]:
        if poplu3.values[i,7] >2 : mintem2 = mintem2 +1
        else : mintem2 = mintem2 -1

        if poplu3.values[i,8] >2 : diftem1 = diftem2 +1
        else : diftem2 = diftem2 -1
        
        if poplu3.values[i,9] >2 : humi2 = humi2 +1
        else : humi2 = humi2 -1 
        
        if poplu5.values[i,2] >2 : ojeon2 = ojeon2 +1
        else : ojeon2= ojeon2 -1

    else :
        if poplu3.values[i,7] <2 : mintem2 = mintem2 +1
        else : mintem2 = mintem2 -1

        if poplu3.values[i,8] <2 : diftem1 = diftem2 +1
        else : diftem2 = diftem2 -1 
        
        if poplu3.values[i,9] <2 : humi2 = humi2 +1
        else : humi2 = humi2 -1 
        
        if poplu5.values[i,2] <2 : ojeon2 = ojeon2 +1
        else : ojeon2= ojeon2 -1

# %%
mintem2, diftem2, humi2, ojeon2
# Out:
# (-101, -155, -21, -193)

# %%
# Out:
#            날짜  시군구지역코드  발생건수(건)        환자평균
# 0    20170101    36110      113  220.183562
# 1    20170102    36110      266  220.183562
# 2    20170103    36110      129  220.183562
# 3    20170104    36110      362  220.183562
# 4    20170105    36110      263  220.183562
# 5    20170106    36110      221  220.183562
# 6    20170107    36110      210  220.183562
# 7    20170108    36110      235  220.183562
# 8    20170109    36110      177  220.183562
# 9    20170110    36110       88  220.183562
# 10   20170111    36110      297  220.183562
# 11   20170112    36110      215  220.183562
# 12   20170113    36110      189  220.183562
# 13   20170114    36110      185  220.183562
# 14   20170115    36110      206  220.183562
# 15   20170116    36110      179  220.183562
# 16   20170117    36110       82  220.183562
# 17   20170118    36110      260  220.183562
# 18   20170119    36110      154  220.183562
# 19   20170120    36110      191  220.183562
# 20   20170121    36110      217  220.183562
# 21   20170122    36110      210  220.183562
# 22   20170123    36110      166  220.183562
# 23   20170124    36110      106  220.183562
# 24   20170125    36110      310  220.183562
# 25   20170126    36110      239  220.183562
# 26   20170127    36110      252  220.183562
# 27   20170128    36110      226  220.183562
# 28   20170129    36110      243  220.183562
# 29   20170130    36110      222  220.183562
# ..        ...      ...      ...         ...
# 335  20171202    36110      338  220.183562
# 336  20171203    36110      315  220.183562
# 337  20171204    36110      180  220.183562
# 338  20171205    36110      485  220.183562
# 339  20171206    36110      332  220.183562
# 340  20171207    36110      310  220.183562
# 341  20171208    36110      360  220.183562
# 342  20171209    36110      348  220.183562
# 343  20171210    36110      322  220.183562
# 344  20171211    36110      138  220.183562
# 345  20171212    36110      450  220.183562
# 346  20171213    36110      352  220.183562
# 347  20171214    36110      337  220.183562
# 348  20171215    36110      389  220.183562
# 349  20171216    36110      384  220.183562
# 350  20171217    36110      327  220.183562
# 351  20171218    36110      139  220.183562
# 352  20171219    36110      517  220.183562
# 353  20171220    36110      426  220.183562
# 354  20171221    36110      348  220.183562
# 355  20171222    36110      342  220.183562
# 356  20171223    36110      356  220.183562
# 357  20171224    36110      297  220.183562
# 358  20171225    36110      124  220.183562
# 359  20171226    36110      443  220.183562
# 360  20171227    36110      347  220.183562
# 361  20171228    36110      315  220.183562
# 362  20171229    36110      316  220.183562
# 363  20171230    36110      301  220.183562
# 364  20171231    36110      252  220.183562
#
# [365 rows x 4 columns]
