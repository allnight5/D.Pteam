# %%
import pandas as pd

# %%
kor_tem3 = pd.read_csv('../Date2/six3.csv' ,thousands=',', encoding='euc-kr')

# %%
kor_tem3.head()
# Out:
#    지역          날짜  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  최저기온위험지수  \
# 0  울산  2016-01-01       4.0      -1.6      12.0        20.0       NaN
# 1  울산  2016-01-02       5.6       0.3      14.2        26.0       NaN
# 2  울산  2016-01-03       7.0       0.7      15.6        36.0       NaN
# 3  울산  2016-01-04       7.7       3.0      13.9        17.0       NaN
# 4  울산  2016-01-05       3.9       0.7       7.8         8.0       NaN
#
#    일교차위험지수  습도위험지수
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN

# %%
for i in kor_tem3.index:
    if kor_tem3.values[i,2] < 17 :
        if kor_tem3.values[i,5] >70:
            kor_tem3['습도위험지수'].values[i] = '1'
        elif 59< kor_tem3.values[i,5] <70:
            kor_tem3['습도위험지수'].values[i] = '2'
        elif 49< kor_tem3.values[i,5] <60:
            kor_tem3['습도위험지수'].values[i] = '3'
        else:
            kor_tem3['습도위험지수'].values[i] = '4'
    elif 17<kor_tem3.values[i,2] < 21:
        if kor_tem3.values[i,5] >60:
            kor_tem3['습도위험지수'].values[i] = '1'
        elif 49< kor_tem3.values[i,5] <60:
            kor_tem3['습도위험지수'].values[i] = '2'
        elif 39< kor_tem3.values[i,5] <50:
            kor_tem3['습도위험지수'].values[i] = '3'
        else:
            kor_tem3['습도위험지수'].values[i] = '4'
            
    elif 20<kor_tem3.values[i,2] < 24:
        if kor_tem3.values[i,5] >50:
            kor_tem3['습도위험지수'].values[i] = '1'
        elif 39< kor_tem3.values[i,5] <50:
            kor_tem3['습도위험지수'].values[i] = '2'
        elif 29< kor_tem3.values[i,5] <40:
            kor_tem3['습도위험지수'].values[i] = '3'
        else:
            kor_tem3['습도위험지수'].values[i] = '4'
    elif kor_tem3.values[i,2] > 23:
        if kor_tem3.values[i,5] >40:
            kor_tem3['습도위험지수'].values[i] = '1'
        elif 29< kor_tem3.values[i,5] <40:
            kor_tem3['습도위험지수'].values[i] = '2'
        elif 19< kor_tem3.values[i,5] <30:
            kor_tem3['습도위험지수'].values[i] = '3'
        else:
            kor_tem3['습도위험지수'].values[i] = '4'

# %%
kor_tem3.head()
# Out:
#    지역          날짜  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  최저기온위험지수  \
# 0  울산  2016-01-01       4.0      -1.6      12.0        20.0       NaN
# 1  울산  2016-01-02       5.6       0.3      14.2        26.0       NaN
# 2  울산  2016-01-03       7.0       0.7      15.6        36.0       NaN
# 3  울산  2016-01-04       7.7       3.0      13.9        17.0       NaN
# 4  울산  2016-01-05       3.9       0.7       7.8         8.0       NaN
#
#    일교차위험지수  습도위험지수
# 0      NaN     4.0
# 1      NaN     4.0
# 2      NaN     4.0
# 3      NaN     4.0
# 4      NaN     4.0

# %%
kor_tem3['일교차'] = kor_tem3['최고기온(°C)'] -  kor_tem3['최저기온(°C)']

# %%
kor_tem3.head()
# Out:
#    지역          날짜  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  최저기온위험지수  \
# 0  울산  2016-01-01       4.0      -1.6      12.0        20.0       NaN
# 1  울산  2016-01-02       5.6       0.3      14.2        26.0       NaN
# 2  울산  2016-01-03       7.0       0.7      15.6        36.0       NaN
# 3  울산  2016-01-04       7.7       3.0      13.9        17.0       NaN
# 4  울산  2016-01-05       3.9       0.7       7.8         8.0       NaN
#
#    일교차위험지수  습도위험지수   일교차
# 0      NaN     4.0  13.6
# 1      NaN     4.0  13.9
# 2      NaN     4.0  14.9
# 3      NaN     4.0  10.9
# 4      NaN     4.0   7.1

# %%
for i in kor_tem3.index:    
    if kor_tem3.values[i,3] <6 or 29<kor_tem3.values[1,2]:
        kor_tem3['최저기온위험지수'].values[i] = '4' 
    elif 5<kor_tem3.values[i,3] <15:
        kor_tem3['최저기온위험지수'].values[i] = '3' 
    elif 14<kor_tem3.values[i,3] <25:
        kor_tem3['최저기온위험지수'].values[i] = '2'  
    elif 24< kor_tem3.values[i,3] <30:
        kor_tem3['최저기온위험지수'].values[i] = '1' 
        
    if kor_tem3.values[i,9] < 3 :  
        kor_tem3['일교차위험지수'].values[i] = '1' 
    elif 2< kor_tem3.values[i,9] < 6: 
        kor_tem3['일교차위험지수'].values[i] = '2'  
    elif 5<kor_tem3.values[i,9] < 10:  
        kor_tem3['일교차위험지수'].values[i] = '3'  
    elif 9< kor_tem3.values[i,9] : 
        kor_tem3['일교차위험지수'].values[i] = '4'

# %%
kor_tem3.head(15)
# Out:
#     지역          날짜  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  최저기온위험지수  \
# 0   울산  2016-01-01       4.0      -1.6      12.0        20.0       4.0
# 1   울산  2016-01-02       5.6       0.3      14.2        26.0       4.0
# 2   울산  2016-01-03       7.0       0.7      15.6        36.0       4.0
# 3   울산  2016-01-04       7.7       3.0      13.9        17.0       4.0
# 4   울산  2016-01-05       3.9       0.7       7.8         8.0       4.0
# 5   울산  2016-01-06       3.9       0.2       8.7        22.0       4.0
# 6   울산  2016-01-07       3.3       0.6       7.2        19.0       4.0
# 7   울산  2016-01-08       2.2      -0.6       6.7        23.0       4.0
# 8   울산  2016-01-09       3.0      -1.3       8.7        24.0       4.0
# 9   울산  2016-01-10       3.1      -2.8       9.8        25.0       4.0
# 10  울산  2016-01-11       3.5       0.3       8.4        11.0       4.0
# 11  울산  2016-01-12       2.0      -1.3       7.7         7.0       4.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform 
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Windows':
    path = "c:/Windows/Fonts/H2HDRM.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

# %%
plt.figure(figsize=(10,6))
plt.plot(kor_tem3.index,kor_tem3['일교차위험지수'], color = 'green')
plt.xlabel('날짜')
plt.ylabel('일교차위험지수')
plt.grid()
plt.show()

# %%
kor_tem3 = pd.read_csv('../Date2/2016ojeon.csv', thousands=',', encoding='euc-kr')

# %%
kor_tem3.head()
# Out:
#            일시  평균 오존전량(DU)  오존위험지수
# 0  2016-01-01        354.9     NaN
# 1  2016-01-02        365.5     NaN
# 2  2016-01-03        373.2     NaN
# 3  2016-01-04        339.8     NaN
# 4  2016-01-05        269.9     NaN

# %%
for i in kor_tem3.index:    
    if kor_tem3.values[i,1] < 300:
        kor_tem3['오존위험지수'].values[i] = '1' 
    elif 299<kor_tem3.values[i,1] <350:
        kor_tem3['오존위험지수'].values[i] = '2' 
    elif 349<kor_tem3.values[i,1] <400:
        kor_tem3['오존위험지수'].values[i] = '3'  
    elif 399< kor_tem3.values[i,1]:
        kor_tem3['오존위험지수'].values[i] = '4'

# %%
kor_tem3.head()
# Out:
#            일시  평균 오존전량(DU)  오존위험지수
# 0  2016-01-01        354.9     3.0
# 1  2016-01-02        365.5     3.0
# 2  2016-01-03        373.2     3.0
# 3  2016-01-04        339.8     2.0
# 4  2016-01-05        269.9     1.0
