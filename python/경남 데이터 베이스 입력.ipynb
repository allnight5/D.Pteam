# %% [markdown]
# # 16년 17년 자료

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
df = pd.read_csv("../data/2016-2017gsouth.csv", thousands=',', encoding='euc-kr')
df1 = pd.read_csv("../data/2016-2017gsouthseek.csv", thousands=',', encoding='euc-kr')
df2 = pd.read_csv("../data/2016-2017ojeon.csv", thousands=',', encoding='euc-kr')
df.head()
# Out:
#      지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  평균 현지기압(hPa)
# 0  경상남도  2016-01-01      -3.1      -8.1       0.9        19.0        1018.9
# 1  경상남도  2016-01-02      -3.3      -9.5       3.9        30.0        1020.5
# 2  경상남도  2016-01-03      -3.0     -11.0       6.8        15.0        1019.6
# 3  경상남도  2016-01-04       0.4      -6.6      12.2        35.0        1014.8
# 4  경상남도  2016-01-05       2.7      -5.3      11.0        38.0        1014.0

# %%
df = pd.merge(df, df1, on="일시")
df.head()
# Out:
#      지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  평균 현지기압(hPa)  \
# 0  경상남도  2016-01-01      -3.1      -8.1       0.9        19.0        1018.9
# 1  경상남도  2016-01-02      -3.3      -9.5       3.9        30.0        1020.5
# 2  경상남도  2016-01-03      -3.0     -11.0       6.8        15.0        1019.6
# 3  경상남도  2016-01-04       0.4      -6.6      12.2        35.0        1014.8
# 4  경상남도  2016-01-05       2.7      -5.3      11.0        38.0        1014.0
#
#   시도지역코드  발생건수(건)
# 0     경남      744
# 1     경남     3985
# 2     경남     2263
# 3     경남      193
# 4     경남     4042

# %%
del df['시도지역코드']

# %%
df.head()
# Out:
#      지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  평균 현지기압(hPa)  \
# 0  경상남도  2016-01-01      -3.1      -8.1       0.9        19.0        1018.9
# 1  경상남도  2016-01-02      -3.3      -9.5       3.9        30.0        1020.5
# 2  경상남도  2016-01-03      -3.0     -11.0       6.8        15.0        1019.6
# 3  경상남도  2016-01-04       0.4      -6.6      12.2        35.0        1014.8
# 4  경상남도  2016-01-05       2.7      -5.3      11.0        38.0        1014.0
#
#    발생건수(건)
# 0      744
# 1     3985
# 2     2263
# 3      193
# 4     4042

# %%
df = pd.merge(df, df2, on="일시")
df.head()
# Out:
#      지점          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  최소 상대습도(%)  평균 현지기압(hPa)  \
# 0  경상남도  2016-01-01      -3.1      -8.1       0.9        19.0        1018.9
# 1  경상남도  2016-01-02      -3.3      -9.5       3.9        30.0        1020.5
# 2  경상남도  2016-01-03      -3.0     -11.0       6.8        15.0        1019.6
# 3  경상남도  2016-01-04       0.4      -6.6      12.2        35.0        1014.8
# 4  경상남도  2016-01-05       2.7      -5.3      11.0        38.0        1014.0
#
#    발생건수(건)  평균 오존전량(DU)
# 0      744        354.9
# 1     3985        365.5
# 2     2263        373.2
# 3      193        339.8
# 4     4042        269.9

# %%
df['최고기온(°C)'] = df['최고기온(°C)'] - df['최저기온(°C)']  
df.rename(columns={ df.columns[0] : '지점',
                    df.columns[1] : '일시',
                    df.columns[2] : '평균기온',
                    df.columns[3] : '최저기온',
                    df.columns[4] : '일교차',
                    df.columns[5] : '최소상대습도',
                    df.columns[6] : '기압',
                    df.columns[7] : '환자수',
                    df.columns[8] : '오존량'},inplace=True)
df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    19.0  1018.9   744  354.9
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    30.0  1020.5  3985  365.5
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    15.0  1019.6  2263  373.2
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    35.0  1014.8   193  339.8
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    38.0  1014.0  4042  269.9

# %%
df['최저기온위험지수'] = 'NaN'
df['일교차위험지수'] = 'NaN'
df['습도위험지수'] = 'NaN'
df['오존위험지수'] = 'NaN'
df['기압위험지수'] = 'NaN'
df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    19.0  1018.9   744  354.9      NaN
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    30.0  1020.5  3985  365.5      NaN
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    15.0  1019.6  2263  373.2      NaN
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    35.0  1014.8   193  339.8      NaN
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    38.0  1014.0  4042  269.9      NaN
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수
# 0     NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN

# %%
#습도는 절대값으로 한다.
for i in df.index:
    if df.values[i,5] >62.5:
        df['습도위험지수'].values[i] = '1'
    elif 62.5<= df.values[i,5] <44.5:
        df['습도위험지수'].values[i] = '2'
    elif 44.5<= df.values[i,5] <30.3:
        df['습도위험지수'].values[i] = '3'
    else:
        df['습도위험지수'].values[i] = '4'
df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    19.0  1018.9   744  354.9      NaN
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    30.0  1020.5  3985  365.5      NaN
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    15.0  1019.6  2263  373.2      NaN
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    35.0  1014.8   193  339.8      NaN
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    38.0  1014.0  4042  269.9      NaN
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수
# 0     NaN      4    NaN    NaN
# 1     NaN      4    NaN    NaN
# 2     NaN      4    NaN    NaN
# 3     NaN      4    NaN    NaN
# 4     NaN      4    NaN    NaN

# %%
for i in df.index:        
    if df.values[i,4] < 8.6 : 
        df['일교차위험지수'].values[i] = '1' 
    elif 8.6<= df.values[i,4] < 12.3: 
        df['일교차위험지수'].values[i] = '2'  
    elif 12.3<=df.values[i,4] < 15.8:  
        df['일교차위험지수'].values[i] = '3'  
    elif 15.8<= df.values[i,4] : 
        df['일교차위험지수'].values[i] = '4' 
            
    if df.values[i,3] <-7.7 or 30<=df.values[1,3]: 
        df['최저기온위험지수'].values[i] = '4' 
    elif -7.7<=df.values[i,3] <-0.5:
        df['최저기온위험지수'].values[i] = '3' 
    elif -0.5<=df.values[i,3] < 12.6:
        df['최저기온위험지수'].values[i] = '2'  
    elif 12.6<=df.values[i,3] <30:
        df['최저기온위험지수'].values[i] = '1'

# %%
for i in df.index:        
    if df.values[i,6] < 1007.6 : 
        df['기압위험지수'].values[i] = '1' 
    elif 1007.6<= df.values[i,6] < 1016.2: 
        df['기압위험지수'].values[i] = '2'  
    elif 1016.2<=df.values[i,6] < 1022.1:  
        df['기압위험지수'].values[i] = '3'  
    elif 1022.1<= df.values[i,6] : 
        df['기압위험지수'].values[i] = '4'

# %%
for i in df.index:
    if df.values[i,8] < 310.8:
        df['오존위험지수'].values[i] = '1'
    elif 310.8<=df.values[i,8] < 348.2:
        df['오존위험지수'].values[i] = '2'
    elif 348.2<=df.values[i,8] < 399.2:
        df['오존위험지수'].values[i] = '3'
    elif 399.2<= df.values[i,8]:
        df['오존위험지수'].values[i] = '4'

# %%
df['최소상대습도'] = 100 - df['최소상대습도']
df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    85.0  1019.6  2263  373.2        4
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    65.0  1014.8   193  339.8        3
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    62.0  1014.0  4042  269.9        3
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수
# 0       2      4      3      3
# 1       3      4      3      3
# 2       4      4      3      3
# 3       4      4      2      2
# 4       4      4      1      2

# %% [markdown]
# # 일교차, 습도, 오존량, 기압, 최저

# %%
temr = df['일교차'].corr(df['환자수'])
hum = df['최소상대습도'].corr(df['환자수'])
oj = df['오존량'].corr(df['환자수'])
atm = df['기압'].corr(df['환자수'])
mtem = -df['최저기온'].corr(df['환자수'])
al = temr+hum+oj+mtem+atm

temr,hum,oj,mtem,atm
# Out:
# (0.08306324817923076,
#  0.11737740817457412,
#  0.13388110295274022,
#  0.27933315600963415,
#  0.23642140376414064)

# %%
temr = temr/al
hum = hum/al
oj = oj/al
atm = atm/al
mtem = mtem/al

temr, hum, oj, atm, mtem
# Out:
# (0.0977126951014177,
#  0.13807867074989494,
#  0.1574930390927528,
#  0.2781178565471864,
#  0.3285977385087482)

# %%
df['ALI'] = float('NaN')
df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    85.0  1019.6  2263  373.2        4
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    65.0  1014.8   193  339.8        3
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    62.0  1014.0  4042  269.9        3
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수  ALI
# 0       2      4      3      3  NaN
# 1       3      4      3      3  NaN
# 2       4      4      3      3  NaN
# 3       4      4      2      2  NaN
# 4       4      4      1      2  NaN

# %%
#temr, hum, oj, atm, mtem
#일교차, 습도, 오존, 기압, 최저기온
for i in df.index:
    df['ALI'].values[i] = mtem*float(df.values[i,9])+temr*float(df.values[i,10])+hum*float(df.values[i,11])+oj*float(df.values[i,12])+ atm*float(df.values[i,13])

df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    85.0  1019.6  2263  373.2        4
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    65.0  1014.8   193  339.8        3
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    62.0  1014.0  4042  269.9        3
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수       ALI
# 0       2      4      3      3  3.368964
# 1       3      4      3      3  3.466676
# 2       4      4      3      3  3.564389
# 3       4      4      2      2  2.800180
# 4       4      4      1      2  2.642687

# %%
df.to_csv("../data/경남2.csv", encoding='utf-8', sep=',')

# %%
la = pd.read_csv("../data/2016-2017gsouthlast.csv", thousands=',', encoding='euc-kr') 
la.head()
# Out:
#    지점          일시
# 0  경남  2016-01-01
# 1  경남  2016-01-02
# 2  경남  2016-01-03
# 3  경남  2016-01-04
# 4  경남  2016-01-05

# %%
la['ALI지수값'] = float('NaN')

# %%
for i in df.index: 
    if float(df.values[i,14]) >= 2.44: 
        la['ALI지수값'].values[i] = '4' 
    elif 1.63<=float(df.values[i,14]) < 2.44: 
        la['ALI지수값'].values[i] = '3' 
    elif 1.31<=float(df.values[i,14]) <1.63: 
        la['ALI지수값'].values[i] = '2' 
    elif 1<= float(df.values[i,14])<1.31: 
        la['ALI지수값'].values[i] = '1' 
la.head()
# Out:
#    지점          일시  ALI지수값
# 0  경남  2016-01-01     4.0
# 1  경남  2016-01-02     4.0
# 2  경남  2016-01-03     4.0
# 3  경남  2016-01-04     4.0
# 4  경남  2016-01-05     4.0

# %%
end = la['ALI지수값'].corr(df['환자수'])
end
# Out:
# 0.21343796421189268

# %%
end = la['ALI지수값'].corr(df['환자수'])
end
# Out:
# 0.21343796421189268

# %%
la.to_csv("../data/경북1.csv", encoding='utf-8', sep=',')

# %%
df['환자'] = df['환자수']/1000

# %%
colormap=df['환자'] 
plt.figure(figsize=(16,5)) 
plt.plot(la['일시'],la['ALI지수값'], color = 'green') 
plt.scatter(df['일시'],df['환자'],s=20,c=colormap,marker='^') 
plt.xticks([0, 100, 200, 300, 400, 500, 600, 710]) 
plt.xlabel('날짜') 
plt.ylabel('ALI지수') 
plt.colorbar() 
plt.grid() 
plt.show()

# %%
import pymysql

# %%
df.head(2)
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수       ALI     환자
# 0       2      4      3      3  3.368964  0.744
# 1       3      4      3      3  3.466676  3.985

# %% [markdown]
# # 조건값

# %%
mtem3 = np.percentile(df['최저기온'], 5)
mtem2 = np.percentile(df['최저기온'], 25)
mtem1 = np.percentile(df['최저기온'], 60) 

mtem1 = float(round(mtem1, 2))
mtem2 = float(round(mtem2, 2))
mtem3 = float(round(mtem3, 2))
mtem1, mtem2, mtem3
Mtem = mtem1, mtem2, mtem3
Mtem
# Out:
# (11.9, -0.48, -7.15)

# %%
pha1 = np.percentile(df['기압'], 95) 
pha2 = np.percentile(df['기압'], 75) 
pha3 = np.percentile(df['기압'], 40) 

pha1 = float(round(pha1, 2))
pha2 = float(round(pha2, 2))
pha3 = float(round(pha3, 2))
pha1, pha2, pha3
Hpa = pha1, pha2, pha3
Hpa
# Out:
# (1025.05, 1018.9, 1010.36)

# %%
Oz1 = np.percentile(df['오존량'], 95)
Oz2 = np.percentile(df['오존량'], 75)
Oz3 = np.percentile(df['오존량'], 40) 

Oz1 = float(round(Oz1, 2))
Oz2 = float(round(Oz2, 2))
Oz3 = float(round(Oz3, 2))
Ozen = (399.23, 348.18, 310.8)
Ozen
# Out:
# (399.23, 348.18, 310.8)

# %%
ra1 = np.percentile(df['일교차'], 95)
ra2 = np.percentile(df['일교차'], 75)
ra3 = np.percentile(df['일교차'], 40) 

ra1 = float(round(ra1, 2))
ra2 = float(round(ra2, 2))
ra3 = float(round(ra3, 2))
ra1, ra2, ra3
Ran = (18.15, 14.7, 10.6)
Ran
# Out:
# (18.15, 14.7, 10.6)

# %%
hum1 = np.percentile(df['최소상대습도'], 5)
hum2 = np.percentile(df['최소상대습도'], 25)
hum3 = np.percentile(df['최소상대습도'], 60) 

hum1 = float(round(hum1, 2))
hum2 = float(round(hum2, 2))
hum3 = float(round(hum3, 2))
hump = hum1, hum2, hum3
hump
# Out:
# (23.27, 47.65, 68.0)

# %%
ALIif1 = np.percentile(df['ALI'], 5)
ALIif2 = np.percentile(df['ALI'], 25)
ALIif3 = np.percentile(df['ALI'], 60)

ALIif1 = float(round(ALIif1, 2))
ALIif2 = float(round(ALIif2, 2))
ALIif3 = float(round(ALIif3, 2))
ALIif = ALIif1, ALIif2, ALIif3
ALIif
# Out:
# (1.28, 1.67, 2.47)

# %% [markdown]
# # 가중치

# %%
temr = float(round(temr, 2))
hum = float(round(hum, 2))
oj = float(round(oj, 2))
atm = float(round(atm, 2))
mtem = float(round(mtem, 2))
temr, hum, oj, atm, mtem
# Out:
# (0.1, 0.14, 0.16, 0.28, 0.33)

# %%
class Weight:
    def __init__(self, idd, Temperange, Huminity, Ozone, Hpa, Mintemper):
        self.idd = idd
        self.Temperange= Temperange
        self.Huminity = Huminity
        self.Ozone = Ozone
        self.Hpa = Hpa
        self.Mintemper = Mintemper

# %%
pas = 'Allday12345!'
def insert_test(data):
    conn = pymysql.connect(host='localhost', port = 8808, user='root', password=pas, db='gyeongsangbuk', charset='utf8')
    try:
        with conn.cursor() as curs:
            sql = 'insert into weight__2016_2017 (id, Temperange, Huminity, Ozone, Hpa, Mintemper) values (%s, %s, %s, %s, %s, %s)'
            curs.execute(sql, (data.idd, data.Temperange, data.Huminity, data.Ozone, data.Hpa, data.Mintemper))
        conn.commit()
    finally:
        conn.close()

# %%
g = 1
if __name__ == "__main__": 
    test = Weight(g, temr, hum, oj, atm, mtem) 
    insert_test(test)

# %%
class IfData:
    def __init__(self, Maxtem, Mintem, Humi, Hpa, Ozone, ALI):
        self.Maxtem = Maxtem
        self.Mintem = Mintem
        self.Humi = Humi
        self.Hpa = Hpa
        self.Ozone = Ozone
        self.ALI = ALI

# %%
pas = 'Allday12345!'
def insert_test(data):
    conn = pymysql.connect(host='localhost', port = 8808, user='root', password=pas, db='gyeongsangbuk', charset='utf8')
    try:
        with conn.cursor() as curs:
            sql = 'insert into gybu_2016_2017 (Maxtem, Mintem, Humi, Hpa, Ozone, ALI) values (%s, %s, %s, %s, %s, %s)'
            curs.execute(sql, (data.Maxtem, data.Mintem, data.Humi, data.Hpa, data.Ozone, data.ALI))
        conn.commit()
    finally:
        conn.close()

# %%
if __name__ == "__main__":  
    for i in range(0, 3):
        test = IfData(Ran[i], Mtem[i], hump[i], Hpa[i], Ozen[i], ALIif[i]) 
        insert_test(test)

# %% [markdown]
# # 습도, 최저기온, 일교차, 기압

# %%
la2 = pd.read_csv("../data/2016-2017gnorthlast.csv", thousands=',', encoding='euc-kr') 
la2['ALI지수값'] = 'NaN'

# %%
temr = df['일교차'].corr(df['환자수'])
hum = df['최소상대습도'].corr(df['환자수']) 
atm = df['기압'].corr(df['환자수'])
mtem = -df['최저기온'].corr(df['환자수'])
al = temr+hum+mtem+atm
temr,hum,mtem,atm
# Out:
# (0.08306324817923076,
#  0.11737740817457412,
#  0.27933315600963415,
#  0.23642140376414064)

# %%
temr = temr/al
hum = hum/al 
atm = atm/al
mtem = mtem/al

temr, hum, atm, mtem
# Out:
# (0.11597850182293631,
#  0.16389024323455556,
#  0.3301074880707185,
#  0.3900237668717897)

# %%
#temr, hum, oj, atm, mtem
#습도 최저 일교차 오존
for i in df.index:
    df['ALI'].values[i] = mtem*float(df.values[i,9])+temr*float(df.values[i,10])+hum*float(df.values[i,11])+atm*float(df.values[i,13])

df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    85.0  1019.6  2263  373.2        4
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    65.0  1014.8   193  339.8        3
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    62.0  1014.0  4042  269.9        3
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수       ALI     환자
# 0       2      4      3      3  3.437936  0.744
# 1       3      4      3      3  3.553914  3.985
# 2       4      4      3      3  3.669893  2.263
# 3       4      4      2      2  2.949761  0.193
# 4       4      4      1      2  2.949761  4.042

# %%
df.to_csv("../data/경북5.csv", encoding='utf-8', sep=',')

# %%
for i in df.index:        
    if float(df.values[i,14]) >= 3.0525:
        la['ALI지수값'].values[i] = '4'
    elif 2.6452<=float(df.values[i,14]) < 3.0525:
        la['ALI지수값'].values[i] = '3'
    elif 1.5354<=float(df.values[i,14]) <2.6452:
        la['ALI지수값'].values[i] = '2'
    elif 1<= float(df.values[i,14])<1.5354:
        la['ALI지수값'].values[i] = '1' 
        
la.head()
# Out:
#    지점          일시  ALI지수값
# 0  경남  2016-01-01     4.0
# 1  경남  2016-01-02     4.0
# 2  경남  2016-01-03     4.0
# 3  경남  2016-01-04     3.0
# 4  경남  2016-01-05     3.0

# %%
end = la['ALI지수값'].corr(df['환자수'])
end
# Out:
# 0.1677695012084004

# %%
colormap=df['환자'] 
plt.figure(figsize=(16,5)) 
plt.plot(la['일시'],la['ALI지수값'], color = 'green') 
plt.scatter(df['일시'],df['환자'],s=20,c=colormap,marker='^') 
plt.xticks([0, 100, 200, 300, 400, 500, 600, 710]) 
plt.xlabel('날짜') 
plt.ylabel('최저기온위험지수') 
plt.colorbar() 
plt.grid() 
plt.show()

# %% [markdown]
# # 일교차, 오존, 기압, 최저기온

# %%
temr = df['일교차'].corr(df['환자수']) 
oj = df['오존량'].corr(df['환자수']) 
atm = df['기압'].corr(df['환자수']) 
mtem = -df['최저기온'].corr(df['환자수']) 
al = temr+oj+mtem+atm
temr,oj,mtem,atm
# Out:
# (0.08306324817923076,
#  0.13388110295274022,
#  0.27933315600963415,
#  0.23642140376414064)

# %%
temr = temr/al 
oj = oj/al 
atm = atm/al 
mtem = mtem/al 
temr,oj,mtem,atm
# Out:
# (0.11336614118417326,
#  0.1827232181732595,
#  0.3812386668683987,
#  0.3226719737741685)

# %%
#temr, hum, oj, atm, mtem
#습도 최저 일교차 오존
#최저, 일교, 습도, 오존, 기압
for i in df.index:
    df['ALI'].values[i] = mtem*float(df.values[i,9])+temr*float(df.values[i,10])+oj*float(df.values[i,12])+atm*float(df.values[i,13])

df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    85.0  1019.6  2263  373.2        4
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    65.0  1014.8   193  339.8        3
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    62.0  1014.0  4042  269.9        3
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수       ALI     환자
# 0       2      4      3      3  3.267873  0.744
# 1       3      4      3      3  3.381239  3.985
# 2       4      4      3      3  3.494605  2.263
# 3       4      4      2      2  2.607971  0.193
# 4       4      4      1      2  2.425248  4.042

# %%
for i in df.index:        
    if float(df.values[i,14]) >= 3.0525:
        la['ALI지수값'].values[i] = '4'
    elif 2.6452<=float(df.values[i,14]) < 3.0525:
        la['ALI지수값'].values[i] = '3'
    elif 1.5354<=float(df.values[i,14]) <2.6452:
        la['ALI지수값'].values[i] = '2'
    elif 1<= float(df.values[i,14])<1.5354:
        la['ALI지수값'].values[i] = '1' 
        
la.head()
# Out:
#    지점          일시  ALI지수값
# 0  경남  2016-01-01     4.0
# 1  경남  2016-01-02     4.0
# 2  경남  2016-01-03     4.0
# 3  경남  2016-01-04     2.0
# 4  경남  2016-01-05     2.0

# %%
end = la['ALI지수값'].corr(df['환자수'])
end
# Out:
# 0.2170293302593119

# %%
colormap=df['환자'] 
plt.figure(figsize=(16,5)) 
plt.plot(la['일시'],la['ALI지수값'], color = 'green') 
plt.scatter(df['일시'],df['환자'],s=20,c=colormap,marker='^') 
plt.xticks([0, 100, 200, 300, 400, 500, 600, 710]) 
plt.xlabel('날짜') 
plt.ylabel('최저기온위험지수') 
plt.colorbar() 
plt.grid() 
plt.show()

# %% [markdown]
# # -----------------------

# %% [markdown]
# # 습도, 오존량, 기압, 최저기온

# %%
hum = df['최소상대습도'].corr(df['환자수'])
oj = df['오존량'].corr(df['환자수'])
atm = df['기압'].corr(df['환자수'])
mtem = -df['최저기온'].corr(df['환자수'])
al = hum+oj+mtem+atm 
hum, oj, atm, mtem
# Out:
# (0.11737740817457412,
#  0.13388110295274022,
#  0.23642140376414064,
#  0.27933315600963415)

# %%
hum = hum/al
oj = oj/al
atm = atm/al
mtem = mtem/al
hum,oj,atm,mtem
# Out:
# (0.15303182256943654,
#  0.17454865898889613,
#  0.30823647305826496,
#  0.36418304538340235)

# %%
#최저, 일교, 습도, 오존, 기압
for i in df.index:
    df['ALI'].values[i] = mtem*float(df.values[i,9])+hum*float(df.values[i,11])+oj*float(df.values[i,12])+atm*float(df.values[i,13])

df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    85.0  1019.6  2263  373.2        4
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    65.0  1014.8   193  339.8        3
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    62.0  1014.0  4042  269.9        3
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수       ALI     환자
# 0       2      4      3      3  3.517215  0.744
# 1       3      4      3      3  3.517215  3.985
# 2       4      4      3      3  3.517215  2.263
# 3       4      4      2      2  2.670247  0.193
# 4       4      4      1      2  2.495698  4.042

# %%
for i in df.index:        
    if float(df.values[i,14]) >= 3.0525:
        la['ALI지수값'].values[i] = '4'
    elif 2.6452<=float(df.values[i,14]) < 3.0525:
        la['ALI지수값'].values[i] = '3'
    elif 1.5354<=float(df.values[i,14]) <2.6452:
        la['ALI지수값'].values[i] = '2'
    elif 1<= float(df.values[i,14])<1.5354:
        la['ALI지수값'].values[i] = '1' 
        
la.head()
# Out:
#    지점          일시  ALI지수값
# 0  경남  2016-01-01     4.0
# 1  경남  2016-01-02     4.0
# 2  경남  2016-01-03     4.0
# 3  경남  2016-01-04     3.0
# 4  경남  2016-01-05     2.0

# %%
end = la['ALI지수값'].corr(df['환자수'])
end
# Out:
# 0.19522980430619435

# %%
colormap=df['환자'] 
plt.figure(figsize=(16,5)) 
plt.plot(la['일시'],la['ALI지수값'], color = 'green') 
plt.scatter(df['일시'],df['환자'],s=20,c=colormap,marker='^') 
plt.xticks([0, 100, 200, 300, 400, 500, 600, 710]) 
plt.xlabel('날짜') 
plt.ylabel('최저기온위험지수') 
plt.colorbar() 
plt.grid() 
plt.show()

# %%
df['all오존'] = df['오존량'].sum()

# %%
df.head()
# Out:
#      지점          일시  평균기온  최저기온   일교차  최소상대습도      기압   환자수    오존량 최저기온위험지수  \
# 0  경상남도  2016-01-01  -3.1  -8.1   9.0    81.0  1018.9   744  354.9        4
# 1  경상남도  2016-01-02  -3.3  -9.5  13.4    70.0  1020.5  3985  365.5        4
# 2  경상남도  2016-01-03  -3.0 -11.0  17.8    85.0  1019.6  2263  373.2        4
# 3  경상남도  2016-01-04   0.4  -6.6  18.8    65.0  1014.8   193  339.8        3
# 4  경상남도  2016-01-05   2.7  -5.3  16.3    62.0  1014.0  4042  269.9        3
#
#   일교차위험지수 습도위험지수 오존위험지수 기압위험지수       ALI     환자     all오존
# 0       2      4      3      3  3.517215  0.744  238176.7
# 1       3      4      3      3  3.517215  3.985  238176.7
# 2       4      4      3      3  3.517215  2.263  238176.7
# 3       4      4      2      2  2.670247  0.193  238176.7
# 4       4      4      1      2  2.495698  4.042  238176.7

# %%
a1= np.percentile(df['오존량'], 95)
a2=np.percentile(df['오존량'], 75)
a3= np.percentile(df['오존량'], 40)
a1, a2, a3
# Out:
# (399.22999999999996, 348.175, 310.8)
